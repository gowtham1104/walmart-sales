# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
a=pd.read_csv("/content/drive/MyDrive/Walmart.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
a.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
a.dropna()
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
data=a.Fuel_Price
plt.plot(data)
plt.show()

# %%
a.drop_duplicates()
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
a.mean()
# Out:
# <ipython-input-30-d6ac9701668a>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.mean()
# Store           2.300000e+01
# Weekly_Sales    1.046965e+06
# Holiday_Flag    6.993007e-02
# Temperature     6.066378e+01
# Fuel_Price      3.358607e+00
# CPI             1.715784e+02
# Unemployment    7.999151e+00
# dtype: float64

# %%
a.median()
# Out:
# <ipython-input-32-d799d54f1221>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.median()
# Store               23.000000
# Weekly_Sales    960746.040000
# Holiday_Flag         0.000000
# Temperature         62.670000
# Fuel_Price           3.445000
# CPI                182.616521
# Unemployment         7.874000
# dtype: float64

# %%
a.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6430    False
# 6431    False
# 6432    False
# 6433    False
# 6434    False
# Length: 6435, dtype: bool

# %%
a.min()
# Out:
# Store                    1
# Date            01-04-2011
# Weekly_Sales     209986.25
# Holiday_Flag             0
# Temperature          -2.06
# Fuel_Price           2.472
# CPI                126.064
# Unemployment         3.879
# dtype: object

# %%
a.max()
# Out:
# Store                   45
# Date            31-12-2010
# Weekly_Sales    3818686.45
# Holiday_Flag             1
# Temperature         100.14
# Fuel_Price           4.468
# CPI             227.232807
# Unemployment        14.313
# dtype: object

# %%
a.std()
# Out:
# <ipython-input-40-7408fc62a40f>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.std()
# Store               12.988182
# Weekly_Sales    564366.622054
# Holiday_Flag         0.255049
# Temperature         18.444933
# Fuel_Price           0.459020
# CPI                 39.356712
# Unemployment         1.875885
# dtype: float64

# %%
a.kurtosis()
# Out:
# <ipython-input-41-d44a27f21237>:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.kurtosis()
# Store          -1.201187
# Weekly_Sales    0.053141
# Holiday_Flag    9.383410
# Temperature    -0.612801
# Fuel_Price     -1.177378
# CPI            -1.839813
# Unemployment    2.639712
# dtype: float64

# %%
data=a.kurtosis()
plt.plot(data)
plt.show
# Out:
# <ipython-input-10-8695c438549f>:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data=a.kurtosis()
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
a.skew()
# Out:
# <ipython-input-43-a03ba72f05af>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.skew()
# Store           0.000000
# Weekly_Sales    0.668362
# Holiday_Flag    3.373499
# Temperature    -0.336768
# Fuel_Price     -0.096158
# CPI             0.063492
# Unemployment    1.188144
# dtype: float64

# %%
data=a.skew()
plt.plot(data)
plt.show
# Out:
# <ipython-input-9-5cbf6e6fdd1b>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data=a.skew()
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=a.mean()
plt.plot(data)
plt.show
# Out:
# <ipython-input-8-73e55258ab3d>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data=a.mean()
# <function matplotlib.pyplot.show(close=None, block=None)>
